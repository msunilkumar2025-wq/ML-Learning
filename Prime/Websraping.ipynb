# %%
# !pip install requests

# %%
import requests

# %%
URL= "https://stephen-king-api.onrender.com/api/books"

res=requests.get(URL)

# %%
json_data= res.json()

# %%
import pandas as pd
df= pd.json_normalize(json_data["data"])
df=df[['Title','Publisher','Year','ISBN']]

# %%
df
# Out:
#               Title        Publisher  Year                  ISBN
# 0            Carrie        Doubleday  1974     978-0-385-08695-0
# 1       Salem's Lot        Doubleday  1975     978-0-385-00751-1
# 2       The Shining        Doubleday  1977     978-0-385-12167-5
# 3              Rage     Signet Books  1977     978-0-451-07645-8
# 4         The Stand        Doubleday  1978     978-0-385-12168-2
# ..              ...              ...   ...                   ...
# 59        Elevation         Scribner  2018     978-1-98210-231-9
# 60    The Institute         Scribner  2019     978-1-98211-056-7
# 61            Later  Hard Case Crime  2021     978-1-78909-649-1
# 62    Billy Summers         Scribner  2021     978-1-982-17361-6
# 63  The Roopak Zone     Viking Press  1979  978-0-670-26069697-5
#
# [64 rows x 4 columns]
